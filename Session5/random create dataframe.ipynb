# %%
import pandas as pd 
import numpy as np 

df = pd.DataFrame(np.random.rand(4,8))
df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.868842  0.619886  0.194713  0.775061  0.995134  0.092805  0.176951
# 1  0.234830  0.070974  0.404862  0.935386  0.470800  0.367062  0.096872
# 2  0.054984  0.854826  0.203358  0.270755  0.585132  0.883719  0.327600
# 3  0.124806  0.343069  0.169646  0.422478  0.349863  0.645968  0.936055
#
#           7
# 0  0.465719
# 1  0.051962
# 2  0.846069
# 3  0.123314

# %%
pd.DataFrame(np.random.rand(4,3),columns=["col1","col2","col3"])
# Out:
#        col1      col2      col3
# 0  0.785493  0.473438  0.587297
# 1  0.154480  0.032684  0.383997
# 2  0.951380  0.773178  0.859345
# 3  0.511922  0.731903  0.259999

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

# %%
df
# Out:
#      A   B   C   D
# 0   33  10   9  22
# 1   15  16  70   1
# 2   67  92  74  60
# 3   75  44   6  59
# 4   60  86  52  87
# ..  ..  ..  ..  ..
# 95  99  96  40  83
# 96  21   0   0  37
# 97  46  41  40  22
# 98   2  64  28  54
# 99  32  84  37  16
#
# [100 rows x 4 columns]

# %%
rng = np.random.default_rng()
df = pd.DataFrame(rng.integers(0, 100, size=(100, 4)), columns=list('ABCD'))

# %%
df
# Out:
#      A   B   C   D
# 0   33  19  36  47
# 1   83  68  97  48
# 2   31  24  29   2
# 3   19  10  44  95
# 4   38  48  21   4
# ..  ..  ..  ..  ..
# 95  40   0   8  23
# 96  49  29  90  32
# 97  44  42  65  15
# 98  69  93  81  82
# 99  38   6  61  21
#
# [100 rows x 4 columns]

# %%
df = pd.DataFrame(np.random.default_rng().choice([2,5,10], size=(100, 4)), columns=['A','B','C','D'])
df
# Out:
#      A   B   C   D
# 0    2  10   2   5
# 1   10  10  10   5
# 2    2  10  10  10
# 3   10   2   2  10
# 4   10  10   2  10
# ..  ..  ..  ..  ..
# 95  10   5   2   2
# 96   2   2  10   2
# 97   5   2   2   5
# 98   5  10  10   5
# 99   5  10  10  10
#
# [100 rows x 4 columns]

# %%
df = pd.DataFrame(np.random.default_rng().choice([2,5], p=[.8,.2], size=(100, 4)), columns=['A','B','C','D'])

# %%
df
# Out:
#     A  B  C  D
# 0   2  5  2  2
# 1   2  2  5  2
# 2   2  2  5  2
# 3   2  2  2  2
# 4   2  2  2  2
# .. .. .. .. ..
# 95  2  2  2  2
# 96  2  2  2  2
# 97  2  5  2  2
# 98  5  2  5  5
# 99  2  5  2  2
#
# [100 rows x 4 columns]

# %%
df=pd.DataFrame(np.random.uniform(0, 1, size=(250, 800)))
df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.792052  0.313493  0.863987  0.862041  0.841584  0.471072  0.435532
# 1    0.291053  0.273612  0.487345  0.613261  0.203837  0.942923  0.023831
# 2    0.801397  0.906689  0.307715  0.748504  0.796933  0.135342  0.016824
# 3    0.425767  0.010491  0.240092  0.535563  0.257271  0.827157  0.278426
# 4    0.156919  0.379027  0.281829  0.977403  0.891495  0.305790  0.984856
# ..        ...       ...       ...       ...       ...       ...       ...
# 245  0.422584  0.681045  0.738644  0.475288  0.020978  0.654020  0.099111
# 246  0.606336  0.471814  0.544407  0.971823  0.052635  0.245823  0.368651
# 247  0.975491  0.145026  0.521834  0.203158  0.749556  0.543250  0.703147
# 248  0.661265  0.062041  0.979871  0.657285  0.466015  0.333544  0.219147
# 249  0.689089  0.425542  0.307234  0.677177  0.381717  0.149990  0.178736
#
#           7         8         9    ...       790       791       792  \
# ...

# %%
df = pd.DataFrame(np.random.default_rng().uniform(low=5,high=10,size=[5000,4]))
df
# Out:
#              0         1         2         3
# 0     5.730673  6.978148  7.934937  6.532084
# 1     9.820303  6.094241  5.380338  9.858960
# 2     5.068428  8.226607  8.422288  6.468561
# 3     6.961555  5.976082  8.654964  7.354556
# 4     8.531070  9.383558  7.955159  6.404901
# ...        ...       ...       ...       ...
# 4995  8.846895  6.303533  7.347275  7.085076
# 4996  5.542483  7.146831  9.238649  8.137226
# 4997  8.399591  6.142308  6.433668  5.781498
# 4998  9.615605  8.066240  7.809926  5.607508
# 4999  8.292405  7.163431  9.809435  5.555041
#
# [5000 rows x 4 columns]
